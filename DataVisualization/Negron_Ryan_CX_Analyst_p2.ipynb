# %% [markdown]
# # CX Analytic Exercise
#
# ## Ryan Negron
#
# ### Part Two

# %% [markdown]
# ### Introduction
# This is the coding notebook that supports the data analysis performed for the second part of the analytic exercise. In this notebook I will be exploring the data and testing different methods to derive insights from the provided spreadsheet.

# %% [markdown]
# ### Import Libraries/Read in Data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cyf_data = pd.read_excel('CX Analyst Exercise Data.xlsx')

# %% [markdown]
# ### EDA

# %%
cyf_data.head()
# Out:
#          RESPONSE_ID      CLIENT_HASH         RECORD_DATE CALLER_NAME  \
# 0  R_6zBXV2ejhO8W0AC  2ABD21D421DFC0B 2024-12-05 21:14:49     Caller6
# 1  R_38CFudGbxdcjGbO  2A6A8166793F050 2024-12-04 17:11:08     Caller6
# 2  R_5hRnVBZZkIWnmzP  FBAACFF252E117B 2025-02-26 15:42:34     Caller6
# 3  R_7JU5TFT1meQEsbT  471245172E02D9B 2025-02-21 18:36:16     Caller6
# 4  R_7ZBSI98GnlRrlOv  CB345B8300A5811 2024-11-15 16:27:16     Caller6
#
#     REGIONAL_OFFICE    SUPERVISOR AGE_CATEGORY                    RACE  \
# 0  Regional Office4   Supervisor6        35-44                   White
# 1  Regional Office3  Supervisor16        35-44                   White
# 2  Regional Office2  Supervisor10        25-34  Black/African American
# 3  Regional Office2  Supervisor14        35-44                   White
# 4  Regional Office3  Supervisor35        35-44  Black/African American
#
#              ETHNICITY       INV_CASE  ...          RESULT_PHONE3  \
# ...

# %%
cyf_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2874 entries, 0 to 2873
# Data columns (total 23 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   RESPONSE_ID                      2874 non-null   object
#  1   CLIENT_HASH                      2874 non-null   object
#  2   RECORD_DATE                      2874 non-null   datetime64[ns]
#  3   CALLER_NAME                      2874 non-null   object
#  4   REGIONAL_OFFICE                  2874 non-null   object
#  5   SUPERVISOR                       2874 non-null   object
#  6   AGE_CATEGORY                     2874 non-null   object
#  7   RACE                             2849 non-null   object
#  8   ETHNICITY                        2849 non-null   object
#  9   INV_CASE                         2874 non-null   object
#  10  DAYS_CASE_INV_OPEN               2862 non-null   float64
# ...

# %%
cyf_data.nunique()
# Out:
# RESPONSE_ID                        2874
# CLIENT_HASH                        2771
# RECORD_DATE                        2874
# CALLER_NAME                           6
# REGIONAL_OFFICE                      10
# SUPERVISOR                           62
# AGE_CATEGORY                          7
# RACE                                  8
# ETHNICITY                             3
# INV_CASE                              3
# DAYS_CASE_INV_OPEN                  285
# RESULT_PHONE1                        14
# RESULT_PHONE2                        17
# RESULT_PHONE3                        14
# CASE_WRKR_EASY_CONTACT                4
# CASE_WRKR_LISTEN_NEED_CONC            4
# CASE_WRKR_ANS_QUEST                   4
# STRG_RELAT_CASE_WRKR                  4
# EXP_CHG_PARENT_SKILLS_CLEANED       366
# RSRC_SERV_FIND_HELPFUL_CLEANED      800
# RSRC_SRVCS_LST_HELPFUL_CLEANED      377
# RSRC_SRVCS_WISH_CONNECT_CLEANED     481
# FIND_POSITIVES_CLEANED              751
# dtype: int64

# %%
cyf_data.isna().sum()
# Out:
# RESPONSE_ID                           0
# CLIENT_HASH                           0
# RECORD_DATE                           0
# CALLER_NAME                           0
# REGIONAL_OFFICE                       0
# SUPERVISOR                            0
# AGE_CATEGORY                          0
# RACE                                 25
# ETHNICITY                            25
# INV_CASE                              0
# DAYS_CASE_INV_OPEN                   12
# RESULT_PHONE1                         0
# RESULT_PHONE2                      1566
# RESULT_PHONE3                      2304
# CASE_WRKR_EASY_CONTACT             1935
# CASE_WRKR_LISTEN_NEED_CONC         1914
# CASE_WRKR_ANS_QUEST                1920
# STRG_RELAT_CASE_WRKR               1922
# EXP_CHG_PARENT_SKILLS_CLEANED      1952
# RSRC_SERV_FIND_HELPFUL_CLEANED     1951
# RSRC_SRVCS_LST_HELPFUL_CLEANED     1995
# RSRC_SRVCS_WISH_CONNECT_CLEANED    1949
# FIND_POSITIVES_CLEANED             1932
# dtype: int64

# %% [markdown]
# ### Initial EDA Plots

# %%
sns.catplot(data = cyf_data, y = 'RACE', kind = 'count', aspect = 2)

plt.show()

# %%
sns.catplot(data = cyf_data, y = 'AGE_CATEGORY', kind = 'count', order = ['24 or under','25-34', '35-44', '45-54', '55-64', '65+', 'Unknown'], aspect = 2)

plt.show()

# %%
sns.catplot(data = cyf_data, y = 'ETHNICITY', kind = 'count', aspect = 2)

plt.show()

# %%
sns.catplot(data = cyf_data, y = 'INV_CASE', kind = 'count', aspect = 2)

plt.show()

# %%
sns.catplot(data = cyf_data, y = 'CALLER_NAME', kind = 'count', order = ['Caller1', 'Caller2', 'Caller3', 'Caller4', 'Caller5', 'Caller6'] ,aspect = 2)

plt.show()

# %%
sns.catplot(data = cyf_data, y = 'REGIONAL_OFFICE', kind = 'count', 
            order = ['Regional Office1','Regional Office2','Regional Office3','Regional Office4','Regional Office5',
                     'Regional Office6', 'Regional Office7','Regional Office8','Regional Office9', 'Regional Office10'],
                     aspect = 2)

plt.show()

# %%
sns.catplot(data = cyf_data, y = 'CASE_WRKR_EASY_CONTACT', kind = 'count', order = ['Yes, completely', 'Mostly yes', 'Mostly no', 'No, not at all'], aspect = 2)

plt.show()

# %%
sns.catplot(data = cyf_data, y = 'CASE_WRKR_LISTEN_NEED_CONC', kind = 'count',order = ['Yes, completely', 'Mostly yes', 'Mostly no', 'No, not at all'], aspect = 2)

plt.show()

# %%
sns.catplot(data = cyf_data, y = 'CASE_WRKR_ANS_QUEST', kind = 'count',order = ['Yes, completely', 'Mostly yes', 'Mostly no', 'No, not at all'] ,aspect = 2)

plt.show()

# %%
sns.catplot(data = cyf_data, y = 'STRG_RELAT_CASE_WRKR', kind = 'count',order = ['Yes, completely', 'Mostly yes', 'Mostly no', 'No, not at all'] ,aspect = 2)

plt.show()

# %%
sns.catplot(data = cyf_data, y = 'RESULT_PHONE1', kind = 'count', aspect = 2)

plt.show()

# %%
sns.catplot(data = cyf_data, y = 'RESULT_PHONE2', kind = 'count', aspect = 2)

plt.show()

# %%
sns.catplot(data = cyf_data, y = 'RESULT_PHONE3', kind = 'count', aspect = 2)

plt.show()

# %%
sns.displot(data = cyf_data, x = 'DAYS_CASE_INV_OPEN', kind = 'hist', aspect = 2)

plt.show()

# %%
sns.displot(data = cyf_data, x = 'DAYS_CASE_INV_OPEN', kind = 'hist', aspect = 2)

plt.xlim(0,250)
plt.show()

# %% [markdown]
# ### Preparing Data for Analysis

# %%
cyf_copy = cyf_data.copy()

# %%
cyf_insight1 = cyf_copy[['RESPONSE_ID', 'CLIENT_HASH', 'RESULT_PHONE1', 'RESULT_PHONE2', 'RESULT_PHONE3']]

# %%
cyf_open = cyf_copy[['RESPONSE_ID', 'CLIENT_HASH','EXP_CHG_PARENT_SKILLS_CLEANED', 
'RSRC_SERV_FIND_HELPFUL_CLEANED', 'RSRC_SRVCS_LST_HELPFUL_CLEANED', 
'RSRC_SRVCS_WISH_CONNECT_CLEANED','FIND_POSITIVES_CLEANED']]

# %%
cyf_open.head()
# Out:
#          RESPONSE_ID      CLIENT_HASH EXP_CHG_PARENT_SKILLS_CLEANED  \
# 0  R_6zBXV2ejhO8W0AC  2ABD21D421DFC0B                           NaN
# 1  R_38CFudGbxdcjGbO  2A6A8166793F050                           NaN
# 2  R_5hRnVBZZkIWnmzP  FBAACFF252E117B                           NaN
# 3  R_7JU5TFT1meQEsbT  471245172E02D9B                           NaN
# 4  R_7ZBSI98GnlRrlOv  CB345B8300A5811                           NaN
#
#   RSRC_SERV_FIND_HELPFUL_CLEANED RSRC_SRVCS_LST_HELPFUL_CLEANED  \
# 0                            NaN                            NaN
# 1                            NaN                            NaN
# 2                            NaN                            NaN
# 3                            NaN                            NaN
# 4                            NaN                            NaN
#
#   RSRC_SRVCS_WISH_CONNECT_CLEANED FIND_POSITIVES_CLEANED
# 0                             NaN                    NaN
# ...

# %%
cyf_clean = cyf_open.fillna('No Response')

# %%
cyf_clean.head()
# Out:
#          RESPONSE_ID      CLIENT_HASH EXP_CHG_PARENT_SKILLS_CLEANED  \
# 0  R_6zBXV2ejhO8W0AC  2ABD21D421DFC0B                   No Response
# 1  R_38CFudGbxdcjGbO  2A6A8166793F050                   No Response
# 2  R_5hRnVBZZkIWnmzP  FBAACFF252E117B                   No Response
# 3  R_7JU5TFT1meQEsbT  471245172E02D9B                   No Response
# 4  R_7ZBSI98GnlRrlOv  CB345B8300A5811                   No Response
#
#   RSRC_SERV_FIND_HELPFUL_CLEANED RSRC_SRVCS_LST_HELPFUL_CLEANED  \
# 0                    No Response                    No Response
# 1                    No Response                    No Response
# 2                    No Response                    No Response
# 3                    No Response                    No Response
# 4                    No Response                    No Response
#
#   RSRC_SRVCS_WISH_CONNECT_CLEANED FIND_POSITIVES_CLEANED
# 0                     No Response            No Response
# ...

# %%
pip install wordcloud
# Out:
# ...
#
# ...

# %%
from wordcloud import WordCloud

# %%
# let's extract each open ended response and drop the 'No Response' entries so we can visualize responses with a word cloud

change_df = cyf_clean[['RESPONSE_ID', 'CLIENT_HASH', 'EXP_CHG_PARENT_SKILLS_CLEANED']].copy()
find_df = cyf_clean[['RESPONSE_ID', 'CLIENT_HASH', 'RSRC_SERV_FIND_HELPFUL_CLEANED']].copy()
least_df = cyf_clean[['RESPONSE_ID', 'CLIENT_HASH', 'RSRC_SRVCS_LST_HELPFUL_CLEANED']].copy()
wish_df = cyf_clean[['RESPONSE_ID', 'CLIENT_HASH', 'RSRC_SRVCS_WISH_CONNECT_CLEANED']].copy()
positive_df = cyf_clean[['RESPONSE_ID', 'CLIENT_HASH', 'FIND_POSITIVES_CLEANED']].copy()

# %%
change_df.drop(change_df[(change_df['EXP_CHG_PARENT_SKILLS_CLEANED'] == 'No Response')].index, inplace = True)

# %%
find_df.drop(find_df[(find_df['RSRC_SERV_FIND_HELPFUL_CLEANED'] == 'No Response')].index, inplace = True)

# %%
least_df.drop(least_df[(least_df['RSRC_SRVCS_LST_HELPFUL_CLEANED'] == 'No Response')].index, inplace = True)

# %%
wish_df.drop(wish_df[(wish_df['RSRC_SRVCS_WISH_CONNECT_CLEANED'] == 'No Response')].index, inplace = True)

# %%
positive_df.drop(positive_df[(positive_df['FIND_POSITIVES_CLEANED'] == 'No Response')].index, inplace = True)

# %% [markdown]
# ### Visualize Word Clouds

# %%
text_change = ''
for line in change_df.EXP_CHG_PARENT_SKILLS_CLEANED:
    text_change += line + " "
wordcloud1 = WordCloud(background_color="white").generate(text_change)
plt.imshow(wordcloud1)
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
text_find = ''
for line in find_df.RSRC_SERV_FIND_HELPFUL_CLEANED:
    text_find += line + " "
wordcloud2 = WordCloud(background_color="white").generate(text_find)
plt.imshow(wordcloud2)
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
text_least = ''
for line in least_df.RSRC_SRVCS_LST_HELPFUL_CLEANED:
    text_least += line + " "
wordcloud3 = WordCloud(background_color="white").generate(text_least)
plt.imshow(wordcloud3)
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
text_wish = ''
for line in wish_df.RSRC_SRVCS_WISH_CONNECT_CLEANED:
    text_wish += line + " "
wordcloud4 = WordCloud(background_color="white").generate(text_wish)
plt.imshow(wordcloud4)
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
text_positive = ''
for line in positive_df.FIND_POSITIVES_CLEANED:
    text_positive += line + " "
wordcloud5 = WordCloud(background_color="white").generate(text_positive)
plt.imshow(wordcloud5)
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %% [markdown]
# ### Sentiment Analysis

# %%
from transformers import pipeline

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification, RobertaForSequenceClassification, RobertaTokenizer, RobertaModel

# %%
from scipy.special import softmax

# %%
from tqdm.notebook import tqdm

# %%
MODEL = f"cardiffnlp/twitter-roberta-base-sentiment"
tokenizer = AutoTokenizer.from_pretrained(MODEL)
model = AutoModelForSequenceClassification.from_pretrained(MODEL)
# Out:
# C:\Users\rnn13\AppData\Roaming\Python\Python311\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %%
def roberta_scores(answer):
    encoded_text = tokenizer(answer, return_tensors='pt', max_length = 511)
    output = model(**encoded_text)
    scores = output[0][0].detach().numpy()
    scores = softmax(scores)
    scores_dict = {
    'neg' : scores[0],
    'neu' : scores[1],
    'pos' : scores[2]
    }
    return scores_dict

# %%
res = {}
for i, row in tqdm(change_df.iterrows(), total = len(change_df)):
    try:
        text = row['EXP_CHG_PARENT_SKILLS_CLEANED']
        myid = row['RESPONSE_ID']
        roberta_result = roberta_scores(text)
        run = {**roberta_result}
        res[myid] = run
    except (RuntimeError, ValueError):
        print(f'Broke for id {myid}')
# Out:
#   0%|          | 0/922 [00:00<?, ?it/s]
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.

# %%
change_sent_df = pd.DataFrame(res).T
change_sent_df = change_sent_df.reset_index().rename(columns = {'index' : 'RESPONSE_ID'})
change_sent_df = change_sent_df.merge(change_df, how = 'left')

# %%
change_sent_df.head()
# Out:
#          RESPONSE_ID       neg       neu       pos      CLIENT_HASH  \
# 0  R_7af4RUvEIEWnVR1  0.002704  0.089784  0.907512  3CBB8051874DF8F
# 1  R_7QEkkc3xPnJq0nk  0.304097  0.472969  0.222933  15870A23A66076B
# 2  R_3xQO0Un21qzmdV8  0.327511  0.458327  0.214162  795F7D924ED6A95
# 3  R_7rzy3hmwMbue7yF  0.327511  0.458327  0.214162  3E8853AFEA881AE
# 4  R_7fdOSqKh7b4A34a  0.304097  0.472969  0.222933  E0B27F16D07E804
#
#                        EXP_CHG_PARENT_SKILLS_CLEANED
# 0  i am using services through the school.  the c...
# 1                                                 no
# 2                                                no.
# 3                                                no.
# 4                                                 no

# %%
res2 = {}
for i, row in tqdm(find_df.iterrows(), total = len(find_df)):
    try:
        text2 = row['RSRC_SERV_FIND_HELPFUL_CLEANED']
        myid2 = row['RESPONSE_ID']
        roberta_result2 = roberta_scores(text2)
        run2 = {**roberta_result2}
        res2[myid2] = run2
    except (RuntimeError, ValueError):
        print(f'Broke for id {myid2}')
# Out:
#   0%|          | 0/923 [00:00<?, ?it/s]

# %%
find_sent_df = pd.DataFrame(res2).T
find_sent_df = find_sent_df.reset_index().rename(columns = {'index' : 'RESPONSE_ID'})
find_sent_df = find_sent_df.merge(find_df, how = 'left')

# %%
find_sent_df.head()
# Out:
#          RESPONSE_ID       neg       neu       pos      CLIENT_HASH  \
# 0  R_7af4RUvEIEWnVR1  0.005540  0.052675  0.941785  3CBB8051874DF8F
# 1  R_7QEkkc3xPnJq0nk  0.304097  0.472969  0.222933  15870A23A66076B
# 2  R_3xQO0Un21qzmdV8  0.380938  0.543104  0.075958  795F7D924ED6A95
# 3  R_7rzy3hmwMbue7yF  0.094114  0.847901  0.057985  3E8853AFEA881AE
# 4  R_7fdOSqKh7b4A34a  0.345507  0.630718  0.023776  E0B27F16D07E804
#
#                       RSRC_SERV_FIND_HELPFUL_CLEANED
# 0  i didn't really use any resources.  i went thr...
# 1                                                 no
# 2                           there were really none.
# 3  being able to talk to them and see what was go...
# 4        none, because he wasn't told any by the cw.

# %%
res3 = {}
for i, row in tqdm(least_df.iterrows(), total = len(least_df)):
    try:
        text3 = row['RSRC_SRVCS_LST_HELPFUL_CLEANED']
        myid3 = row['RESPONSE_ID']
        roberta_result3 = roberta_scores(text3)
        run3 = {**roberta_result3}
        res3[myid3] = run3
    except (RuntimeError, ValueError):
        print(f'Broke for id {myid3}')
# Out:
#   0%|          | 0/879 [00:00<?, ?it/s]

# %%
least_sent_df = pd.DataFrame(res3).T
least_sent_df = least_sent_df.reset_index().rename(columns = {'index' : 'RESPONSE_ID'})
least_sent_df = least_sent_df.merge(least_df, how = 'left')

# %%
least_sent_df.head()
# Out:
#          RESPONSE_ID       neg       neu       pos      CLIENT_HASH  \
# 0  R_7af4RUvEIEWnVR1  0.327511  0.458327  0.214162  3CBB8051874DF8F
# 1  R_7QEkkc3xPnJq0nk  0.304097  0.472969  0.222933  15870A23A66076B
# 2  R_3xQO0Un21qzmdV8  0.380938  0.543104  0.075958  795F7D924ED6A95
# 3  R_7rzy3hmwMbue7yF  0.327511  0.458327  0.214162  3E8853AFEA881AE
# 4  R_7fdOSqKh7b4A34a  0.233605  0.559524  0.206870  E0B27F16D07E804
#
#   RSRC_SRVCS_LST_HELPFUL_CLEANED
# 0                            no.
# 1                             no
# 2       there were really none.
# 3                            no.
# 4                           none

# %%
res4 = {}
for i, row in tqdm(wish_df.iterrows(), total = len(wish_df)):
    try:
        text4 = row['RSRC_SRVCS_WISH_CONNECT_CLEANED']
        myid4 = row['RESPONSE_ID']
        roberta_result4 = roberta_scores(text4)
        run4 = {**roberta_result4}
        res4[myid4] = run4
    except (RuntimeError, ValueError):
        print(f'Broke for id {myid4}')
# Out:
#   0%|          | 0/925 [00:00<?, ?it/s]

# %%
wish_sent_df = pd.DataFrame(res4).T
wish_sent_df = wish_sent_df.reset_index().rename(columns = {'index' : 'RESPONSE_ID'})
wish_sent_df = wish_sent_df.merge(wish_df, how = 'left')

# %%
wish_sent_df.head()
# Out:
#          RESPONSE_ID       neg       neu       pos      CLIENT_HASH  \
# 0  R_7af4RUvEIEWnVR1  0.270520  0.627148  0.102332  3CBB8051874DF8F
# 1  R_7QEkkc3xPnJq0nk  0.304097  0.472969  0.222933  15870A23A66076B
# 2  R_1dbDBDYbKm0SCKp  0.237806  0.606232  0.155962  4660DBF8C735078
# 3  R_3xQO0Un21qzmdV8  0.311258  0.645768  0.042974  795F7D924ED6A95
# 4  R_7rzy3hmwMbue7yF  0.327511  0.458327  0.214162  3E8853AFEA881AE
#
#                      RSRC_SRVCS_WISH_CONNECT_CLEANED
# 0                                  no, there wasn't.
# 1                                                 no
# 2  i would have liked cyf/cw to help me with lett...
# 3                                     i'm not sure.
# 4                                                no.

# %%
res5 = {}
for i, row in tqdm(positive_df.iterrows(), total = len(positive_df)):
    try:
        text5 = row['FIND_POSITIVES_CLEANED']
        myid5 = row['RESPONSE_ID']
        roberta_result5 = roberta_scores(text5)
        run5 = {**roberta_result5}
        res5[myid5] = run5
    except (RuntimeError, ValueError):
        print(f'Broke for id {myid5}')
# Out:
#   0%|          | 0/942 [00:00<?, ?it/s]

# %%
positive_sent_df = pd.DataFrame(res5).T
positive_sent_df = positive_sent_df.reset_index().rename(columns = {'index' : 'RESPONSE_ID'})
positive_sent_df = positive_sent_df.merge(positive_df, how = 'left')

# %%
positive_sent_df.head()
# Out:
#          RESPONSE_ID       neg       neu       pos      CLIENT_HASH  \
# 0  R_7af4RUvEIEWnVR1  0.107481  0.819461  0.073059  3CBB8051874DF8F
# 1  R_7QEkkc3xPnJq0nk  0.742963  0.243642  0.013396  15870A23A66076B
# 2  R_1dbDBDYbKm0SCKp  0.089448  0.446286  0.464266  4660DBF8C735078
# 3  R_3xQO0Un21qzmdV8  0.260750  0.685320  0.053930  795F7D924ED6A95
# 4  R_7rzy3hmwMbue7yF  0.426523  0.466174  0.107303  3E8853AFEA881AE
#
#                               FIND_POSITIVES_CLEANED
# 0        knowing who to call if i do need services.
# 1  she doesnt know why cyf even started an invest...
# 2  in all the years they’ve been going through al...
# 3                i don't know.  it stayed the same.
# 4                                       no. nothing.

# %% [markdown]
# ## Insights

# %% [markdown]
# ### Insight 1

# %%
cyf_clean['RECORD_DATE'] = cyf_data['RECORD_DATE'].copy()

# %%
cyf_clean['RESULT_PHONE1'] = cyf_data['RESULT_PHONE1'].copy()

# %%
cyf_clean.head()
# Out:
#          RESPONSE_ID      CLIENT_HASH EXP_CHG_PARENT_SKILLS_CLEANED  \
# 0  R_6zBXV2ejhO8W0AC  2ABD21D421DFC0B                   No Response
# 1  R_38CFudGbxdcjGbO  2A6A8166793F050                   No Response
# 2  R_5hRnVBZZkIWnmzP  FBAACFF252E117B                   No Response
# 3  R_7JU5TFT1meQEsbT  471245172E02D9B                   No Response
# 4  R_7ZBSI98GnlRrlOv  CB345B8300A5811                   No Response
#
#   RSRC_SERV_FIND_HELPFUL_CLEANED RSRC_SRVCS_LST_HELPFUL_CLEANED  \
# 0                    No Response                    No Response
# 1                    No Response                    No Response
# 2                    No Response                    No Response
# 3                    No Response                    No Response
# 4                    No Response                    No Response
#
#   RSRC_SRVCS_WISH_CONNECT_CLEANED FIND_POSITIVES_CLEANED         RECORD_DATE  \
# 0                     No Response            No Response 2024-12-05 21:14:49
# ...

# %%
cyf_insight1.head()
# Out:
#          RESPONSE_ID      CLIENT_HASH  \
# 0  R_6zBXV2ejhO8W0AC  2ABD21D421DFC0B
# 1  R_38CFudGbxdcjGbO  2A6A8166793F050
# 2  R_5hRnVBZZkIWnmzP  FBAACFF252E117B
# 3  R_7JU5TFT1meQEsbT  471245172E02D9B
# 4  R_7ZBSI98GnlRrlOv  CB345B8300A5811
#
#                                   RESULT_PHONE1          RESULT_PHONE2  \
# 0                         Disconnected/inactive                    NaN
# 1                                  Left message                    NaN
# 2                         Disconnected/inactive  Disconnected/inactive
# 3  Answered and not interested in participating                    NaN
# 4             Answered and wants to participate  Disconnected/inactive
#
#            RESULT_PHONE3
# 0                    NaN
# 1                    NaN
# 2  Disconnected/inactive
# 3                    NaN
# 4  Disconnected/inactive

# %%
cyf_insight1 = cyf_insight1.fillna('None Provided.')

# %%
cyf_insight1.head()
# Out:
#          RESPONSE_ID      CLIENT_HASH  \
# 0  R_6zBXV2ejhO8W0AC  2ABD21D421DFC0B
# 1  R_38CFudGbxdcjGbO  2A6A8166793F050
# 2  R_5hRnVBZZkIWnmzP  FBAACFF252E117B
# 3  R_7JU5TFT1meQEsbT  471245172E02D9B
# 4  R_7ZBSI98GnlRrlOv  CB345B8300A5811
#
#                                   RESULT_PHONE1          RESULT_PHONE2  \
# 0                         Disconnected/inactive         None Provided.
# 1                                  Left message         None Provided.
# 2                         Disconnected/inactive  Disconnected/inactive
# 3  Answered and not interested in participating         None Provided.
# 4             Answered and wants to participate  Disconnected/inactive
#
#            RESULT_PHONE3
# 0         None Provided.
# 1         None Provided.
# 2  Disconnected/inactive
# 3         None Provided.
# 4  Disconnected/inactive

# %%
answered_list = ['Answered and wants to participate', 'Received call back and wants to participate',
                 'Received call back and does not want to participate', 
                 'Answered and not interested in participating', 'Asked for call back']

# %%
cyf_insight1['Contacted?'] = cyf_insight1.apply(lambda row: 'Able to be contacted' if row ['RESULT_PHONE1'] in answered_list or row['RESULT_PHONE2'] in answered_list or row['RESULT_PHONE3'] in answered_list else 'Unable to be contacted', axis = 1)

# %%
cyf_insight1.head()
# Out:
#          RESPONSE_ID      CLIENT_HASH  \
# 0  R_6zBXV2ejhO8W0AC  2ABD21D421DFC0B
# 1  R_38CFudGbxdcjGbO  2A6A8166793F050
# 2  R_5hRnVBZZkIWnmzP  FBAACFF252E117B
# 3  R_7JU5TFT1meQEsbT  471245172E02D9B
# 4  R_7ZBSI98GnlRrlOv  CB345B8300A5811
#
#                                   RESULT_PHONE1          RESULT_PHONE2  \
# 0                         Disconnected/inactive         None Provided.
# 1                                  Left message         None Provided.
# 2                         Disconnected/inactive  Disconnected/inactive
# 3  Answered and not interested in participating         None Provided.
# 4             Answered and wants to participate  Disconnected/inactive
#
#            RESULT_PHONE3              Contacted?
# 0         None Provided.  Unable to be contacted
# 1         None Provided.  Unable to be contacted
# 2  Disconnected/inactive  Unable to be contacted
# 3         None Provided.    Able to be contacted
# 4  Disconnected/inactive    Able to be contacted

# %%
ax = sns.countplot(data = cyf_insight1, x = 'Contacted?', palette = 'colorblind')
total = cyf_insight1['Contacted?'].count()
for c in ax.containers:
    ax.bar_label(c, fmt=lambda x: f'{(x/total)*100:0.1f}%')

plt.show()

# %% [markdown]
# ### Insight 2

# %%
cyf_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2874 entries, 0 to 2873
# Data columns (total 23 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   RESPONSE_ID                      2874 non-null   object
#  1   CLIENT_HASH                      2874 non-null   object
#  2   RECORD_DATE                      2874 non-null   datetime64[ns]
#  3   CALLER_NAME                      2874 non-null   object
#  4   REGIONAL_OFFICE                  2874 non-null   object
#  5   SUPERVISOR                       2874 non-null   object
#  6   AGE_CATEGORY                     2874 non-null   object
#  7   RACE                             2849 non-null   object
#  8   ETHNICITY                        2849 non-null   object
#  9   INV_CASE                         2874 non-null   object
#  10  DAYS_CASE_INV_OPEN               2862 non-null   float64
# ...

# %%
insight2_list = ['RESPONSE_ID', 'CLIENT_HASH', 'RECORD_DATE',
                 'CASE_WRKR_EASY_CONTACT', 'CASE_WRKR_LISTEN_NEED_CONC',
                 'CASE_WRKR_ANS_QUEST', 'STRG_RELAT_CASE_WRKR']

# %%
cyf_insight2 = cyf_data[insight2_list].copy()

# %%
cyf_insight2 = cyf_insight2.fillna('No Response')

# %%
cyf_insight2.head()
# Out:
#          RESPONSE_ID      CLIENT_HASH         RECORD_DATE  \
# 0  R_6zBXV2ejhO8W0AC  2ABD21D421DFC0B 2024-12-05 21:14:49
# 1  R_38CFudGbxdcjGbO  2A6A8166793F050 2024-12-04 17:11:08
# 2  R_5hRnVBZZkIWnmzP  FBAACFF252E117B 2025-02-26 15:42:34
# 3  R_7JU5TFT1meQEsbT  471245172E02D9B 2025-02-21 18:36:16
# 4  R_7ZBSI98GnlRrlOv  CB345B8300A5811 2024-11-15 16:27:16
#
#   CASE_WRKR_EASY_CONTACT CASE_WRKR_LISTEN_NEED_CONC CASE_WRKR_ANS_QUEST  \
# 0            No Response                No Response         No Response
# 1            No Response                No Response         No Response
# 2            No Response                No Response         No Response
# 3            No Response                No Response         No Response
# 4            No Response                No Response         No Response
#
#   STRG_RELAT_CASE_WRKR
# 0          No Response
# 1          No Response
# 2          No Response
# 3          No Response
# 4          No Response

# %%
cyf_insight2['Day of Week'] = cyf_insight2['RECORD_DATE'].dt.day_name()

# %%
cyf_insight2.head()
# Out:
#          RESPONSE_ID      CLIENT_HASH         RECORD_DATE  \
# 0  R_6zBXV2ejhO8W0AC  2ABD21D421DFC0B 2024-12-05 21:14:49
# 1  R_38CFudGbxdcjGbO  2A6A8166793F050 2024-12-04 17:11:08
# 2  R_5hRnVBZZkIWnmzP  FBAACFF252E117B 2025-02-26 15:42:34
# 3  R_7JU5TFT1meQEsbT  471245172E02D9B 2025-02-21 18:36:16
# 4  R_7ZBSI98GnlRrlOv  CB345B8300A5811 2024-11-15 16:27:16
#
#   CASE_WRKR_EASY_CONTACT CASE_WRKR_LISTEN_NEED_CONC CASE_WRKR_ANS_QUEST  \
# 0            No Response                No Response         No Response
# 1            No Response                No Response         No Response
# 2            No Response                No Response         No Response
# 3            No Response                No Response         No Response
# 4            No Response                No Response         No Response
#
#   STRG_RELAT_CASE_WRKR Day of Week
# 0          No Response    Thursday
# 1          No Response   Wednesday
# 2          No Response   Wednesday
# 3          No Response      Friday
# ...

# %%
cyf_insight2['Time of Day'] = cyf_isnight2['RECORD_DATE'].dt.time

# %%
cyf_insight2.head()
# Out:
#          RESPONSE_ID      CLIENT_HASH         RECORD_DATE  \
# 0  R_6zBXV2ejhO8W0AC  2ABD21D421DFC0B 2024-12-05 21:14:49
# 1  R_38CFudGbxdcjGbO  2A6A8166793F050 2024-12-04 17:11:08
# 2  R_5hRnVBZZkIWnmzP  FBAACFF252E117B 2025-02-26 15:42:34
# 3  R_7JU5TFT1meQEsbT  471245172E02D9B 2025-02-21 18:36:16
# 4  R_7ZBSI98GnlRrlOv  CB345B8300A5811 2024-11-15 16:27:16
#
#   CASE_WRKR_EASY_CONTACT CASE_WRKR_LISTEN_NEED_CONC CASE_WRKR_ANS_QUEST  \
# 0            No Response                No Response         No Response
# 1            No Response                No Response         No Response
# 2            No Response                No Response         No Response
# 3            No Response                No Response         No Response
# 4            No Response                No Response         No Response
#
#   STRG_RELAT_CASE_WRKR Day of Week Time of Day
# 0          No Response    Thursday    21:14:49
# 1          No Response   Wednesday    17:11:08
# ...

# %%
no_participate_list = ['No Response']

# %%
cyf_insight2['Participated?'] = cyf_insight2.apply(lambda row: 'Did NOT Participate in Survey' 
                                                   if row ['CASE_WRKR_EASY_CONTACT'] in no_participate_list or 
                                                   row ['CASE_WRKR_LISTEN_NEED_CONC'] in no_participate_list or 
                                                   row ['CASE_WRKR_ANS_QUEST'] in no_participate_list or
                                                   row ['STRG_RELAT_CASE_WRKR'] in no_participate_list else
                                                   'Participated in Survey', axis = 1)

# %%
day_order = ['Sunday', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday']
cyf_insight2['Day of Week'] = pd.Categorical(cyf_insight2['Day of Week'], categories=day_order, ordered=True)

# %%
ax2 = sns.countplot(data=cyf_insight2, y='Participated?', hue='Day of Week', palette='colorblind', order=cyf_insight2['Participated?'].value_counts().index)
total2 = cyf_insight2['Participated?'].count()
for c in ax2.containers:
    ax2.bar_label(c, fmt=lambda x: f'{(x/total2)*100:0.1f}%')

plt.show()

# %% [markdown]
# ### Insight 3

# %%
cyf_insight3 = cyf_insight2.copy()
cyf_insight3['SUPERVISOR'] = cyf_data['SUPERVISOR']
cyf_insight3['REGIONAL_OFFICE'] = cyf_data['REGIONAL_OFFICE']

# %%
sns.catplot(data = cyf_insight3, y = 'CASE_WRKR_EASY_CONTACT' , col = 'SUPERVISOR', kind = 'count', col_wrap = 6)

plt.show()

# %%
sns.catplot(data = cyf_insight3, y = 'CASE_WRKR_EASY_CONTACT' , col = 'REGIONAL_OFFICE', order = ['Yes, completely', 'Mostly yes', 'Mostly no', 'No, not at all', 'No Response'], kind = 'count', col_wrap = 3)

plt.show()

# %%
sns.catplot(data = cyf_insight3, y = 'CASE_WRKR_LISTEN_NEED_CONC' , col = 'REGIONAL_OFFICE', order = ['Yes, completely', 'Mostly yes', 'Mostly no', 'No, not at all', 'No Response'], kind = 'count', col_wrap = 3)

plt.show()

# %%
sns.catplot(data = cyf_insight3, y = 'CASE_WRKR_ANS_QUEST' , col = 'REGIONAL_OFFICE', order = ['Yes, completely', 'Mostly yes', 'Mostly no', 'No, not at all', 'No Response'], kind = 'count', col_wrap = 3)

plt.show()

# %%
sns.catplot(data = cyf_insight3, y = 'STRG_RELAT_CASE_WRKR' , col = 'REGIONAL_OFFICE', order = ['Yes, completely', 'Mostly yes', 'Mostly no', 'No, not at all', 'No Response'], kind = 'count', col_wrap = 3)

plt.show()
